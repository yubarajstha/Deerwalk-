# %% [markdown]
# da

# %% [markdown]
# # day 17

# %%
scores = [-390,56,70,65,75,80,85,90,95,100,102,104,40,200]
import matplotlib.pyplot as plt
import numpy as np
data = np.array(scores)
Q1 = np.percentile(data, 25)
Q3 = np.percentile(data, 75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5*IQR
upper_bound = Q3 - 1.5*IQR
outliers = data[(data< lower_bound)  | data > upper_bound]
print("Q1:", Q1)
print("Q3:", Q1)
print("IQR:", IQR)
print("lower bound:", lower_bound)
print("upper bound:", upper_bound)
print("Outliers:", outliers)

plt.boxplot(data, vert= False)
plt.title("Box plot of student scsores with outliers")
plt.xlabel("Scores")
plt.show()
# Out:
# Q1: 66.25
# Q3: 66.25
# IQR: 32.5
# lower bound: 17.5
# upper bound: 50.0
# Outliers: [ 56  70  65  75  80  85  90  95 100 102 104 200]
