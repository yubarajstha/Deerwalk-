# %% [markdown]
# ## pandas

# %%
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import pandas as pd
#
# ModuleNotFoundError: No module named 'pandas'

# %%
pip install pandas
# Out:
# ...
#    ---------------------------------------- 0.0/11.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/11.0 MB ? eta -:--:--
#    -- ------------------------------------- 0.8/11.0 MB 3.4 MB/s eta 0:00:03
#    --- ------------------------------------ 1.0/11.0 MB 2.7 MB/s eta 0:00:04
#    ----- ---------------------------------- 1.6/11.0 MB 2.6 MB/s eta 0:00:04
#    ------ --------------------------------- 1.8/11.0 MB 2.4 MB/s eta 0:00:04
#    ------- -------------------------------- 2.1/11.0 MB 1.9 MB/s eta 0:00:05
#    ------- -------------------------------- 2.1/11.0 MB 1.9 MB/s eta 0:00:05
#    -------- ------------------------------- 2.4/11.0 MB 1.7 MB/s eta 0:00:06
#    --------- ------------------------------ 2.6/11.0 MB 1.6 MB/s eta 0:00:06
#    ---------- ----------------------------- 2.9/11.0 MB 1.4 MB/s eta 0:00:06
#    ---------- ----------------------------- 2.9/11.0 MB 1.4 MB/s eta 0:00:06
# ...

# %%
import pandas as pd

# %%
x = {
    'Name': ['Rose', 'John', 'Jane', 'Mary'],
    'ID': [1, 2, 3, 4],
    'Department': ["Computer Science", 'Education', "Humanity", "Finance"],
    'Salary': [100000, 80000, 50000, 60000]
}
# casting the dictonary to a daraframe
df=pd.DataFrame(x)
df
# Out:
#    Name  ID        Department  Salary
# 0  Rose   1  Computer Science  100000
# 1  John   2         Education   80000
# 2  Jane   3          Humanity   50000
# 3  Mary   4           Finance   60000

# %%
#retrieving the id column 
x= df[['ID']]
x
# Out:
#    ID
# 0   1
# 1   2
# 2   3
# 3   4

# %%
type(x)
# Out:
# pandas.core.frame.DataFrame

# %%
# multiple column access

# %%
z= df[['Department','Salary',"ID"]]
z
# Out:
#          Department  Salary  ID
# 0  Computer Science  100000   1
# 1         Education   80000   2
# 2          Humanity   50000   3
# 3           Finance   60000   4

# %%
y = {
    'Student': ['David', 'Samuel', 'Terry', 'Evan'],
    'Age': [27, 24, 22, 32],
    'Country': ['UK', 'Canada', 'China', 'USA'],
    'Course': ['Python', 'Data Structure', 'Machine Learning', 'Web Development'],
    'Marks': [85, 72, 89, 76]
}
df= pd.DataFrame(y)
df
# Out:
#   Student  Age Country            Course  Marks
# 0   David   27      UK            Python     85
# 1  Samuel   24  Canada    Data Structure     72
# 2   Terry   22   China  Machine Learning     89
# 3    Evan   32     USA   Web Development     76

# %%
b=df[["Marks"]]
b
# Out:
#    Marks
# 0     85
# 1     72
# 2     89
# 3     76

# %%
y=df["Student"]
y
# Out:
# 0     David
# 1    Samuel
# 2     Terry
# 3      Evan
# Name: Student, dtype: object

# %%
type(y)
# Out:
# pandas.core.series.Series

# %%
df.iloc[0,0]
# Out:
# 'David'

# %%
df.iloc[0,2]
# Out:
# 'UK'

# %%
df.loc[0,'Course']
# Out:
# 'Python'

# %%
df.loc[1,'Country']
# Out:
# 'Canada'

# %%
# set index name
df2=df
df2=df2.set_index("Student")
df2.head()
# Out:
#          Age Country            Course  Marks
# Student
# David     27      UK            Python     85
# Samuel    24  Canada    Data Structure     72
# Terry     22   China  Machine Learning     89
# Evan      32     USA   Web Development     76

# %%
df2.loc['Terry','Marks']
# Out:
# np.int64(89)

# %%
pip install numpy as np
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement as (from versions: none)
# ERROR: No matching distribution found for as

# %%
pip install numpy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install numpy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
df2.loc['Terry','Marks']
# Out:
# np.int64(89)

# %%
df.iloc[0:2,0:3]
# Out:
#   Student  Age Country
# 0   David   27      UK
# 1  Samuel   24  Canada

# %%
df.loc[0:2,"Age":"Course"]
# Out:
#    Age Country            Course
# 0   27      UK            Python
# 1   24  Canada    Data Structure
# 2   22   China  Machine Learning

# %%
pip install numpy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# loading data 
filename = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-PY0101EN-SkillsNetwork/labs/Module%204/data/TopSellingAlbums.csv"
df = pd.read_csv(filename)
df
# Out:
#             Artist                            Album  Released   Length  \
# 0  Michael Jackson                         Thriller      1982  0:42:19
# 1            AC/DC                    Back in Black      1980  0:42:11
# 2       Pink Floyd        The Dark Side of the Moon      1973  0:42:49
# 3  Whitney Houston                    The Bodyguard      1992  0:57:44
# 4        Meat Loaf                  Bat Out of Hell      1977  0:46:33
# 5           Eagles  Their Greatest Hits (1971-1975)      1976  0:43:08
# 6         Bee Gees             Saturday Night Fever      1977  1:15:54
# 7    Fleetwood Mac                          Rumours      1977  0:40:01
#
#                          Genre  Music Recording Sales (millions)  \
# 0               pop, rock, R&B                              46.0
# 1                    hard rock                              26.1
# 2             progressive rock                              24.2
# 3               R&B, soul, pop                              27.4
# ...

# %%
x= df[["Length"]]
x
# Out:
#     Length
# 0  0:42:19
# 1  0:42:11
# 2  0:42:49
# 3  0:57:44
# 4  0:46:33
# 5  0:43:08
# 6  1:15:54
# 7  0:40:01

# %%
type(x)
# Out:
# pandas.core.frame.DataFrame

# %%
y=df['Length']
type(y)
# Out:
# pandas.core.series.Series

# %%
y= df[["Length","Artist","Released"]]
y
# Out:
#     Length           Artist  Released
# 0  0:42:19  Michael Jackson      1982
# 1  0:42:11            AC/DC      1980
# 2  0:42:49       Pink Floyd      1973
# 3  0:57:44  Whitney Houston      1992
# 4  0:46:33        Meat Loaf      1977
# 5  0:43:08           Eagles      1976
# 6  1:15:54         Bee Gees      1977
# 7  0:40:01    Fleetwood Mac      1977
